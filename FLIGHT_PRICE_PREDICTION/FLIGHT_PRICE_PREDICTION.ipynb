# %% [markdown]
# ![AIRPLANE%20LOGO%20DESIGN.png](attachment:AIRPLANE%20LOGO%20DESIGN.png)

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Problem Statement</h1>
#
# </div>

# %% [markdown]
# ###  Client had a problem in predicting the price of ticket for a flight

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Data Gathering and Validation</h1>
#
# </div>

# %% [markdown]
# #### The objective of the case study is to analyse the flight booking dataset obtained from “Ease My Trip” website and to conduct various statistical hypothesis tests in order to get meaningful information from it. 'Easemytrip' is an internet platform for booking flight tickets. A thorough study of the data will aid in the discovery of valuable insights that will be of enormous value to passengers. Overall, I have to build a model that can precisely predict the ticket price.

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Brain Storming</h1>
#
# </div>

# %% [markdown]
# ##### By getting problem of the client, i have some questions in my mind, which are follow
#
# ##### a) Does price vary with Airlines?
#
# ##### b) How is the price affected when tickets are bought in just 1 or 2 days before departure?
#
# ##### c) Does ticket price change based on the departure time and arrival time?
#
# ##### d) How the price changes with change in Source and Destination?
#
# ##### e) How does the ticket price vary between Economy and Business class?, etc
#
# #### Data is seperated in to two parts:
# ##### one for economy class tickets and another for business class tickets.
#
# ##### A total of 300261 distinct flight booking options are available. And these are for 50 days, from February 11th to March 31st, 2022.

# %%
import pandas as pd
import numpy as np
import json
import pickle
import warnings 
warnings.filterwarnings("ignore")
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor, \
GradientBoostingRegressor, BaggingRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.svm import LinearSVR
import IPython

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Loading The Files in Dataframes</h1>
#
# </div>

# %%
df_bus=pd.read_csv('business.csv')

# %%
df_bus.head(5)
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m
#
#                                                 stop arr_time      to   price
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450
# 4  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  46,690

# %%
df_ec=pd.read_csv('economy.csv')

# %%
df_ec.head(5)
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Initial Preprocessing</h1>
#
# </div>
#
# #### as we can see the there is high noise in the data. So, we will do some cleaning and also drive some relevent featues from the given data
#
# #### we will drive new featue named class to specify in which class the ticket is booked
#
# #### we wil drive new featute named flight by adding ch_code and num_code of the flight
#
# #### we will drive new feature days left by subtracting the booking date from journey date

# %%
df_bus["class"] = "business"
df_ec["class"] = "economy"

# %%
df_bus
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# 4      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...                                                  ...      ...        ...
# 93482  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 93483  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 93484  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 93485  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 93486  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#         price     class
# 0      25,612  business
# 1      25,612  business
# 2      42,220  business
# 3      44,450  business
# 4      46,690  business
# ...       ...       ...
# 93482  69,265  business
# 93483  77,105  business
# 93484  79,099  business
# 93485  81,585  business
# 93486  81,585  business
#
# [93487 rows x 12 columns]

# %%
# appending two data sets and storing in the new data frame
df=df_ec.append(df_bus,ignore_index = True) 
df.head(50)
# Out:
#           date    airline ch_code  num_code dep_time   from time_taken  \
# 0   11-02-2022   SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1   11-02-2022   SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2   11-02-2022    AirAsia      I5       764    04:25  Delhi    02h 10m
# 3   11-02-2022    Vistara      UK       995    10:20  Delhi    02h 15m
# 4   11-02-2022    Vistara      UK       963    08:50  Delhi    02h 20m
# 5   11-02-2022    Vistara      UK       945    11:40  Delhi    02h 20m
# 6   11-02-2022    Vistara      UK       927    09:30  Delhi    02h 05m
# 7   11-02-2022    Vistara      UK       951    14:20  Delhi    02h 10m
# 8   11-02-2022   GO FIRST      G8       334    08:00  Delhi    02h 10m
# 9   11-02-2022   GO FIRST      G8       336    14:20  Delhi    02h 15m
# 10  11-02-2022   GO FIRST      G8       392    15:00  Delhi    02h 15m
# 11  11-02-2022   GO FIRST      G8       338    10:30  Delhi    02h 20m
# 12  11-02-2022     Indigo      6E      5001    07:15  Delhi    02h 10m
# 13  11-02-2022     Indigo      6E      6202    12:00  Delhi    02h 10m
# 14  11-02-2022     Indigo      6E       549    14:20  Delhi    02h 15m
# 15  11-02-2022     Indigo      6E      6278    08:45  Delhi    02h 20m
# 16  11-02-2022  Air India      AI       887    07:00  Delhi    02h 05m
# 17  11-02-2022  Air India      AI       665    08:00  Delhi    02h 10m
# 18  11-02-2022    AirAsia      I5       747    19:00  Delhi    12h 15m
# 19  11-02-2022    AirAsia      I5       747    19:00  Delhi    16h 20m
# 20  11-02-2022   GO FIRST      G8       266    06:25  Delhi    11h 45m
# 21  11-02-2022   GO FIRST      G8       101    05:50  Delhi    14h 30m
# 22  11-02-2022   GO FIRST      G8       103    19:25  Delhi    15h 40m
# 23  11-02-2022  Air India      AI       441    17:50  Delhi    03h 45m
# 24  11-02-2022     Indigo      6E      5328    09:30  Delhi    02h 30m
# 25  11-02-2022    Vistara      UK       933    15:30  Delhi    02h 10m
# 26  11-02-2022     Indigo      6E      2046    17:15  Delhi    02h 10m
# 27  11-02-2022    AirAsia      I5       744    08:20  Delhi    05h 50m
# 28  11-02-2022   SpiceJet      SG      8169    19:45  Delhi    02h 20m
# 29  11-02-2022     Indigo      6E      5041    18:40  Delhi    02h 10m
# 30  11-02-2022   GO FIRST      G8       165    06:05  Delhi    08h 00m
# 31  11-02-2022     Indigo      6E      2373    13:50  Delhi    06h 00m
# 32  11-02-2022    Vistara      UK       813    17:35  Delhi    14h 40m
# 33  11-02-2022    Vistara      UK       817    16:05  Delhi    16h 10m
# 34  11-02-2022    Vistara      UK       819    14:15  Delhi    18h 00m
# 35  11-02-2022    Vistara      UK       801    09:05  Delhi    23h 10m
# 36  11-02-2022    Vistara      UK       815    08:05  Delhi    24h 10m
# 37  11-02-2022  Air India      AI       453    04:55  Delhi    08h 50m
# 38  11-02-2022   SpiceJet      SG      2976    19:20  Delhi    04h 30m
# 39  11-02-2022   SpiceJet      SG      2976    19:20  Delhi    15h 15m
# 40  11-02-2022  Air India      AI       504    21:35  Delhi    11h 00m
# 41  11-02-2022  Air India      AI       502    13:30  Delhi    19h 05m
# 42  11-02-2022  Air India      AI       506    09:45  Delhi    22h 50m
# 43  11-02-2022  Air India      AI       803    06:10  Delhi    26h 25m
# 44  11-02-2022  Air India      AI       479    21:15  Delhi    17h 45m
# 45  11-02-2022   SpiceJet      SG       339    17:00  Delhi    19h 35m
# 46  11-02-2022    Vistara      UK       955    17:45  Delhi    02h 20m
# 47  11-02-2022    Vistara      UK       627    13:20  Delhi    26h 40m
# 48  11-02-2022    AirAsia      I5       784    16:05  Delhi    15h 10m
# 49  11-02-2022  Air India      AI      9643    19:00  Delhi    20h 50m
#
#                                                  stop arr_time      to  \
# 0                                           non-stop     21:05  Mumbai
# 1                                           non-stop     08:40  Mumbai
# 2                                           non-stop     06:35  Mumbai
# 3                                           non-stop     12:35  Mumbai
# 4                                           non-stop     11:10  Mumbai
# 5                                           non-stop     14:00  Mumbai
# 6                                           non-stop     11:35  Mumbai
# 7                                           non-stop     16:30  Mumbai
# 8                                           non-stop     10:10  Mumbai
# 9                                           non-stop     16:35  Mumbai
# 10                                          non-stop     17:15  Mumbai
# 11                                          non-stop     12:50  Mumbai
# 12                                          non-stop     09:25  Mumbai
# 13                                          non-stop     14:10  Mumbai
# 14                                          non-stop     16:35  Mumbai
# 15                                          non-stop     11:05  Mumbai
# 16                                          non-stop     09:05  Mumbai
# 17                                          non-stop     10:10  Mumbai
# 18  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    07:15  Mumbai
# 19  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    11:20  Mumbai
# 20  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    18:10  Mumbai
# 21  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:20  Mumbai
# 22  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    11:05  Mumbai
# 23  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\...    21:35  Mumbai
# 24                                          non-stop     12:00  Mumbai
# 25                                          non-stop     17:40  Mumbai
# 26                                          non-stop     19:25  Mumbai
# 27  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    14:10  Mumbai
# 28                                          non-stop     22:05  Mumbai
# 29                                          non-stop     20:50  Mumbai
# 30  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    14:05  Mumbai
# 31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Mumbai
# 32  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:15  Mumbai
# 33  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:15  Mumbai
# 34  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:15  Mumbai
# 35  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:15  Mumbai
# 36  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:15  Mumbai
# 37  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    13:45  Mumbai
# 38  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:50  Mumbai
# 39  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    10:35  Mumbai
# 40  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:35  Mumbai
# 41  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:35  Mumbai
# 42  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:35  Mumbai
# 43  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    08:35  Mumbai
# 44  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    15:00  Mumbai
# 45  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    12:35  Mumbai
# 46                                          non-stop     20:05  Mumbai
# 47  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    16:00  Mumbai
# 48  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    07:15  Mumbai
# 49  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    15:50  Mumbai
#
#      price    class
# 0    5,953  economy
# 1    5,953  economy
# 2    5,956  economy
# 3    5,955  economy
# 4    5,955  economy
# 5    5,955  economy
# 6    6,060  economy
# 7    6,060  economy
# 8    5,954  economy
# 9    5,954  economy
# 10   5,954  economy
# 11   5,954  economy
# 12   5,955  economy
# 13   5,955  economy
# 14   5,955  economy
# 15   5,955  economy
# 16   5,955  economy
# 17   5,955  economy
# 18   5,949  economy
# 19   5,949  economy
# 20   5,954  economy
# 21   5,954  economy
# 22   5,954  economy
# 23   5,955  economy
# 24   6,165  economy
# 25   6,690  economy
# 26   6,585  economy
# 27   8,869  economy
# 28  10,260  economy
# 29  10,470  economy
# 30  10,575  economy
# 31  10,838  economy
# 32  12,150  economy
# 33  12,150  economy
# 34  12,150  economy
# 35  12,150  economy
# 36  12,150  economy
# 37  11,900  economy
# 38  12,123  economy
# 39  12,123  economy
# 40  12,150  economy
# 41  12,150  economy
# 42  12,150  economy
# 43  12,150  economy
# 44  12,215  economy
# 45  12,230  economy
# 46  12,780  economy
# 47  12,885  economy
# 48  12,539  economy
# 49  12,938  economy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  object
#  11  class       300261 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 27.5+ MB

# %%
# merging two columns (ch_code and "num_code") and making new feature flight
df.num_code = df.num_code.astype("str")
df["flight"] = df["ch_code"] +"-"+ df["num_code"]
df.drop(["ch_code","num_code"],axis = 1,inplace = True)

# %%
# renaming the featuers
df.rename({"dep_time": "departure_time", "from": "source_city", 
            "time_taken": "duration", "stop": "stops", "arr_time": "arrival_time",
           "to":"destination_city"}, axis = 1, inplace = True)

# %%
dd = pd.DataFrame(df["date"].str.split("-",expand = True).to_numpy().astype(int),columns = ["day","month","year"])
df["days_left"] = np.where(dd["month"] > 2, dd["day"] +18, np.where(dd["month"] == 2, dd["day"] -10, dd["day"]))

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day

# %%
# as we drived one feature on the basis of date so no need for this featue so we will drop it
df.drop("date",axis = 1,inplace = True)

# %%
# converting time into morning/noon/evening, etc
d=(pd.to_datetime(df["departure_time"]).dt.hour % 24 + 4)//4
d.replace({1:'Late Night', 2:'Early Morning',3:'Morning',4:'Afternoon',5:'Evening',6:'Night'},inplace=True)
df['departure_time']=d

# %%
df.head(5)
# Out:
#     airline departure_time source_city duration      stops arrival_time  \
# 0  SpiceJet        Evening       Delhi  02h 10m  non-stop         21:05
# 1  SpiceJet  Early Morning       Delhi  02h 20m  non-stop         08:40
# 2   AirAsia  Early Morning       Delhi  02h 10m  non-stop         06:35
# 3   Vistara        Morning       Delhi  02h 15m  non-stop         12:35
# 4   Vistara        Morning       Delhi  02h 20m  non-stop         11:10
#
#   destination_city  price    class   flight  days_left  year  month  day
# 0           Mumbai  5,953  economy  SG-8709          1  2022     11    2
# 1           Mumbai  5,953  economy  SG-8157          1  2022     11    2
# 2           Mumbai  5,956  economy   I5-764          1  2022     11    2
# 3           Mumbai  5,955  economy   UK-995          1  2022     11    2
# 4           Mumbai  5,955  economy   UK-963          1  2022     11    2

# %%
# we also can get morning eveniing categories by making bins
#  our bins are (0,4,8,12,16,20,24) respected labels starts from "latenight" to "night"
temp = pd.DataFrame(df["arrival_time"].str.split(":",expand = True).to_numpy().astype(int), 
                    columns = ["hour","minute"])
df["arrival_time"] = pd.cut(x = temp["hour"], bins = 6, labels = 
                             ["Late Night","Early Morning","Morning", "Afternoon", "Evening", "Night"])
df.head(1)
# Out:
#     airline departure_time source_city duration      stops arrival_time  \
# 0  SpiceJet        Evening       Delhi  02h 10m  non-stop         Night
#
#   destination_city  price    class   flight  days_left  year  month  day
# 0           Mumbai  5,953  economy  SG-8709          1  2022     11    2

# %%
df
# Out:
#          airline departure_time source_city duration  \
# 0       SpiceJet        Evening       Delhi  02h 10m
# 1       SpiceJet  Early Morning       Delhi  02h 20m
# 2        AirAsia  Early Morning       Delhi  02h 10m
# 3        Vistara        Morning       Delhi  02h 15m
# 4        Vistara        Morning       Delhi  02h 20m
# ...          ...            ...         ...      ...
# 300256   Vistara        Morning     Chennai  10h 05m
# 300257   Vistara      Afternoon     Chennai  10h 25m
# 300258   Vistara  Early Morning     Chennai  13h 50m
# 300259   Vistara  Early Morning     Chennai  10h 00m
# 300260   Vistara        Morning     Chennai  10h 05m
#
#                                                     stops   arrival_time  \
# 0                                               non-stop           Night
# 1                                               non-stop         Morning
# 2                                               non-stop   Early Morning
# 3                                               non-stop       Afternoon
# 4                                               non-stop         Morning
# ...                                                   ...            ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Evening
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...          Night
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...          Night
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Evening
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Evening
#
#        destination_city   price     class   flight  days_left  year  month  \
# 0                Mumbai   5,953   economy  SG-8709          1  2022     11
# 1                Mumbai   5,953   economy  SG-8157          1  2022     11
# 2                Mumbai   5,956   economy   I5-764          1  2022     11
# 3                Mumbai   5,955   economy   UK-995          1  2022     11
# 4                Mumbai   5,955   economy   UK-963          1  2022     11
# ...                 ...     ...       ...      ...        ...   ...    ...
# 300256        Hyderabad  69,265  business   UK-822         49  2022      3
# 300257        Hyderabad  77,105  business   UK-826         49  2022      3
# 300258        Hyderabad  79,099  business   UK-832         49  2022      3
# 300259        Hyderabad  81,585  business   UK-828         49  2022      3
# 300260        Hyderabad  81,585  business   UK-822         49  2022      3
#
#         day
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
# ...     ...
# 300256   31
# 300257   31
# 300258   31
# 300259   31
# 300260   31
#
# [300261 rows x 14 columns]

# %%
# making duration in float values by calculating only hours
temp = pd.DataFrame(df["duration"].str.split(expand = True).to_numpy().astype(str), 
                    columns = ["hour","minute"])
temp["hour"] = temp["hour"].apply(lambda x: re.sub("[^0-9]","",x)).astype(int)
temp["minute"] = temp["minute"].apply(lambda r: re.sub("[^0-9]","",r))
temp["minute"] = np.where(temp["minute"] == "", 0, temp["minute"])
temp["minute"] = temp["minute"].astype(int)
df["duration"] = np.around((temp["hour"] + (temp["minute"]/60)),2)

# %%
df.head(5)
# Out:
#     airline departure_time source_city  duration      stops   arrival_time  \
# 0  SpiceJet        Evening       Delhi      2.17  non-stop           Night
# 1  SpiceJet  Early Morning       Delhi      2.33  non-stop         Morning
# 2   AirAsia  Early Morning       Delhi      2.17  non-stop   Early Morning
# 3   Vistara        Morning       Delhi      2.25  non-stop       Afternoon
# 4   Vistara        Morning       Delhi      2.33  non-stop         Morning
#
#   destination_city  price    class   flight  days_left  year  month  day
# 0           Mumbai  5,953  economy  SG-8709          1  2022     11    2
# 1           Mumbai  5,953  economy  SG-8157          1  2022     11    2
# 2           Mumbai  5,956  economy   I5-764          1  2022     11    2
# 3           Mumbai  5,955  economy   UK-995          1  2022     11    2
# 4           Mumbai  5,955  economy   UK-963          1  2022     11    2

# %%
# # removing noise from price column
df["price"] = df["price"].apply(lambda r: re.sub("[^0-9]","",r))

# %%
df["price"] = df["price"].astype(int)

# %%
df.head(50)
# Out:
#       airline departure_time source_city  duration  \
# 0    SpiceJet        Evening       Delhi      2.17
# 1    SpiceJet  Early Morning       Delhi      2.33
# 2     AirAsia  Early Morning       Delhi      2.17
# 3     Vistara        Morning       Delhi      2.25
# 4     Vistara        Morning       Delhi      2.33
# 5     Vistara        Morning       Delhi      2.33
# 6     Vistara        Morning       Delhi      2.08
# 7     Vistara      Afternoon       Delhi      2.17
# 8    GO FIRST        Morning       Delhi      2.17
# 9    GO FIRST      Afternoon       Delhi      2.25
# 10   GO FIRST      Afternoon       Delhi      2.25
# 11   GO FIRST        Morning       Delhi      2.33
# 12     Indigo  Early Morning       Delhi      2.17
# 13     Indigo      Afternoon       Delhi      2.17
# 14     Indigo      Afternoon       Delhi      2.25
# 15     Indigo        Morning       Delhi      2.33
# 16  Air India  Early Morning       Delhi      2.08
# 17  Air India        Morning       Delhi      2.17
# 18    AirAsia        Evening       Delhi     12.25
# 19    AirAsia        Evening       Delhi     16.33
# 20   GO FIRST  Early Morning       Delhi     11.75
# 21   GO FIRST  Early Morning       Delhi     14.50
# 22   GO FIRST        Evening       Delhi     15.67
# 23  Air India        Evening       Delhi      3.75
# 24     Indigo        Morning       Delhi      2.50
# 25    Vistara      Afternoon       Delhi      2.17
# 26     Indigo        Evening       Delhi      2.17
# 27    AirAsia        Morning       Delhi      5.83
# 28   SpiceJet        Evening       Delhi      2.33
# 29     Indigo        Evening       Delhi      2.17
# 30   GO FIRST  Early Morning       Delhi      8.00
# 31     Indigo      Afternoon       Delhi      6.00
# 32    Vistara        Evening       Delhi     14.67
# 33    Vistara        Evening       Delhi     16.17
# 34    Vistara      Afternoon       Delhi     18.00
# 35    Vistara        Morning       Delhi     23.17
# 36    Vistara        Morning       Delhi     24.17
# 37  Air India  Early Morning       Delhi      8.83
# 38   SpiceJet        Evening       Delhi      4.50
# 39   SpiceJet        Evening       Delhi     15.25
# 40  Air India          Night       Delhi     11.00
# 41  Air India      Afternoon       Delhi     19.08
# 42  Air India        Morning       Delhi     22.83
# 43  Air India  Early Morning       Delhi     26.42
# 44  Air India          Night       Delhi     17.75
# 45   SpiceJet        Evening       Delhi     19.58
# 46    Vistara        Evening       Delhi      2.33
# 47    Vistara      Afternoon       Delhi     26.67
# 48    AirAsia        Evening       Delhi     15.17
# 49  Air India        Evening       Delhi     20.83
#
#                                                 stops   arrival_time  \
# 0                                           non-stop           Night
# 1                                           non-stop         Morning
# 2                                           non-stop   Early Morning
# 3                                           non-stop       Afternoon
# 4                                           non-stop         Morning
# 5                                           non-stop       Afternoon
# 6                                           non-stop         Morning
# 7                                           non-stop         Evening
# 8                                           non-stop         Morning
# 9                                           non-stop         Evening
# 10                                          non-stop         Evening
# 11                                          non-stop       Afternoon
# 12                                          non-stop         Morning
# 13                                          non-stop       Afternoon
# 14                                          non-stop         Evening
# 15                                          non-stop         Morning
# 16                                          non-stop         Morning
# 17                                          non-stop         Morning
# 18  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...  Early Morning
# 19  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 20  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Evening
# 21  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...          Night
# 22  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 23  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\...          Night
# 24                                          non-stop       Afternoon
# 25                                          non-stop         Evening
# 26                                          non-stop         Evening
# 27  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...      Afternoon
# 28                                          non-stop           Night
# 29                                          non-stop           Night
# 30  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...      Afternoon
# 31  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Evening
# 32  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 33  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 34  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 35  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 36  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 37  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...      Afternoon
# 38  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...          Night
# 39  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 40  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 41  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 42  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 43  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Morning
# 44  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...      Afternoon
# 45  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...      Afternoon
# 46                                          non-stop           Night
# 47  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        Evening
# 48  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...  Early Morning
# 49  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...      Afternoon
#
#    destination_city  price    class   flight  days_left  year  month  day
# 0            Mumbai   5953  economy  SG-8709          1  2022     11    2
# 1            Mumbai   5953  economy  SG-8157          1  2022     11    2
# 2            Mumbai   5956  economy   I5-764          1  2022     11    2
# 3            Mumbai   5955  economy   UK-995          1  2022     11    2
# 4            Mumbai   5955  economy   UK-963          1  2022     11    2
# 5            Mumbai   5955  economy   UK-945          1  2022     11    2
# 6            Mumbai   6060  economy   UK-927          1  2022     11    2
# 7            Mumbai   6060  economy   UK-951          1  2022     11    2
# 8            Mumbai   5954  economy   G8-334          1  2022     11    2
# 9            Mumbai   5954  economy   G8-336          1  2022     11    2
# 10           Mumbai   5954  economy   G8-392          1  2022     11    2
# 11           Mumbai   5954  economy   G8-338          1  2022     11    2
# 12           Mumbai   5955  economy  6E-5001          1  2022     11    2
# 13           Mumbai   5955  economy  6E-6202          1  2022     11    2
# 14           Mumbai   5955  economy   6E-549          1  2022     11    2
# 15           Mumbai   5955  economy  6E-6278          1  2022     11    2
# 16           Mumbai   5955  economy   AI-887          1  2022     11    2
# 17           Mumbai   5955  economy   AI-665          1  2022     11    2
# 18           Mumbai   5949  economy   I5-747          1  2022     11    2
# 19           Mumbai   5949  economy   I5-747          1  2022     11    2
# 20           Mumbai   5954  economy   G8-266          1  2022     11    2
# 21           Mumbai   5954  economy   G8-101          1  2022     11    2
# 22           Mumbai   5954  economy   G8-103          1  2022     11    2
# 23           Mumbai   5955  economy   AI-441          1  2022     11    2
# 24           Mumbai   6165  economy  6E-5328          1  2022     11    2
# 25           Mumbai   6690  economy   UK-933          1  2022     11    2
# 26           Mumbai   6585  economy  6E-2046          1  2022     11    2
# 27           Mumbai   8869  economy   I5-744          1  2022     11    2
# 28           Mumbai  10260  economy  SG-8169          1  2022     11    2
# 29           Mumbai  10470  economy  6E-5041          1  2022     11    2
# 30           Mumbai  10575  economy   G8-165          1  2022     11    2
# 31           Mumbai  10838  economy  6E-2373          1  2022     11    2
# 32           Mumbai  12150  economy   UK-813          1  2022     11    2
# 33           Mumbai  12150  economy   UK-817          1  2022     11    2
# 34           Mumbai  12150  economy   UK-819          1  2022     11    2
# 35           Mumbai  12150  economy   UK-801          1  2022     11    2
# 36           Mumbai  12150  economy   UK-815          1  2022     11    2
# 37           Mumbai  11900  economy   AI-453          1  2022     11    2
# 38           Mumbai  12123  economy  SG-2976          1  2022     11    2
# 39           Mumbai  12123  economy  SG-2976          1  2022     11    2
# 40           Mumbai  12150  economy   AI-504          1  2022     11    2
# 41           Mumbai  12150  economy   AI-502          1  2022     11    2
# 42           Mumbai  12150  economy   AI-506          1  2022     11    2
# 43           Mumbai  12150  economy   AI-803          1  2022     11    2
# 44           Mumbai  12215  economy   AI-479          1  2022     11    2
# 45           Mumbai  12230  economy   SG-339          1  2022     11    2
# 46           Mumbai  12780  economy   UK-955          1  2022     11    2
# 47           Mumbai  12885  economy   UK-627          1  2022     11    2
# 48           Mumbai  12539  economy   I5-784          1  2022     11    2
# 49           Mumbai  12938  economy  AI-9643          1  2022     11    2

# %%
df.stops.unique()
# Out:
# array(['non-stop ',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Chennai\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Indore\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia RPR\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '2+-stop',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Lucknow\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GOP\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Raipur\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Nagpur\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Surat\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Hyderabad\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia STV\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IDR\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia VTZ\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Guwahati\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia NAG\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Vishakhapatnam\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia NDC\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXE\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Patna\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia PAT\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Mangalore\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Mumbai\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia KLH\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia MYQ\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Kolkata\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Delhi\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Kolhapur\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia JRG\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Bhubaneswar\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Ranchi\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXR\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia JGB\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia BBI\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Mysore\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAY\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GAU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia HYD\n\t\t\t\t\t\t\t\t\t\t\t\t'],
#       dtype=object)

# %%
# making the stops in numeric data type by giving stops accordingly
df['stops'] = df['stops'].str.replace(r'\W', "")

# %%
df.stops.unique()
# Out:
# array(['nonstop', '1stop', '1stopViaIXU', '1stopViaChennai',
#        '1stopViaIndore', '1stopViaRPR', '2stop', '1stopViaLucknow',
#        '1stopViaGOP', '1stopViaRaipur', '1stopViaNagpur', '1stopViaSurat',
#        '1stopViaHyderabad', '1stopViaSTV', '1stopViaIDR', '1stopViaVTZ',
#        '1stopViaGuwahati', '1stopViaNAG', '1stopViaVishakhapatnam',
#        '1stopViaNDC', '1stopViaIXE', '1stopViaPatna', '1stopViaPAT',
#        '1stopViaMangalore', '1stopViaMumbai', '1stopViaKLH',
#        '1stopViaMYQ', '1stopViaKolkata', '1stopViaDelhi',
#        '1stopViaKolhapur', '1stopViaJRG', '1stopViaBhubaneswar',
#        '1stopViaRanchi', '1stopViaIXR', '1stopViaJGB', '1stopViaBBI',
#        '1stopViaMysore', '1stopViaGAY', '1stopViaGAU', '1stopViaHYD'],
#       dtype=object)

# %%
df.stops.replace({'nonstop':'0'}, inplace=True)
df.stops.unique()
# Out:
# array(['0', '1stop', '1stopViaIXU', '1stopViaChennai', '1stopViaIndore',
#        '1stopViaRPR', '2stop', '1stopViaLucknow', '1stopViaGOP',
#        '1stopViaRaipur', '1stopViaNagpur', '1stopViaSurat',
#        '1stopViaHyderabad', '1stopViaSTV', '1stopViaIDR', '1stopViaVTZ',
#        '1stopViaGuwahati', '1stopViaNAG', '1stopViaVishakhapatnam',
#        '1stopViaNDC', '1stopViaIXE', '1stopViaPatna', '1stopViaPAT',
#        '1stopViaMangalore', '1stopViaMumbai', '1stopViaKLH',
#        '1stopViaMYQ', '1stopViaKolkata', '1stopViaDelhi',
#        '1stopViaKolhapur', '1stopViaJRG', '1stopViaBhubaneswar',
#        '1stopViaRanchi', '1stopViaIXR', '1stopViaJGB', '1stopViaBBI',
#        '1stopViaMysore', '1stopViaGAY', '1stopViaGAU', '1stopViaHYD'],
#       dtype=object)

# %%
df["stops"] = df["stops"].str.replace(r'\D', "")

# %%
df.stops.unique()
# Out:
# array(['0', '1', '2'], dtype=object)

# %%
df.head(5)
# Out:
#     airline departure_time source_city  duration stops   arrival_time  \
# 0  SpiceJet        Evening       Delhi      2.17     0          Night
# 1  SpiceJet  Early Morning       Delhi      2.33     0        Morning
# 2   AirAsia  Early Morning       Delhi      2.17     0  Early Morning
# 3   Vistara        Morning       Delhi      2.25     0      Afternoon
# 4   Vistara        Morning       Delhi      2.33     0        Morning
#
#   destination_city  price    class   flight  days_left  year  month  day
# 0           Mumbai   5953  economy  SG-8709          1  2022     11    2
# 1           Mumbai   5953  economy  SG-8157          1  2022     11    2
# 2           Mumbai   5956  economy   I5-764          1  2022     11    2
# 3           Mumbai   5955  economy   UK-995          1  2022     11    2
# 4           Mumbai   5955  economy   UK-963          1  2022     11    2

# %%
df.drop(['year','month','day'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#     airline departure_time source_city  duration stops   arrival_time  \
# 0  SpiceJet        Evening       Delhi      2.17     0          Night
# 1  SpiceJet  Early Morning       Delhi      2.33     0        Morning
# 2   AirAsia  Early Morning       Delhi      2.17     0  Early Morning
# 3   Vistara        Morning       Delhi      2.25     0      Afternoon
# 4   Vistara        Morning       Delhi      2.33     0        Morning
# 5   Vistara        Morning       Delhi      2.33     0      Afternoon
# 6   Vistara        Morning       Delhi      2.08     0        Morning
# 7   Vistara      Afternoon       Delhi      2.17     0        Evening
# 8  GO FIRST        Morning       Delhi      2.17     0        Morning
# 9  GO FIRST      Afternoon       Delhi      2.25     0        Evening
#
#   destination_city  price    class   flight  days_left
# 0           Mumbai   5953  economy  SG-8709          1
# 1           Mumbai   5953  economy  SG-8157          1
# 2           Mumbai   5956  economy   I5-764          1
# 3           Mumbai   5955  economy   UK-995          1
# 4           Mumbai   5955  economy   UK-963          1
# 5           Mumbai   5955  economy   UK-945          1
# 6           Mumbai   6060  economy   UK-927          1
# 7           Mumbai   6060  economy   UK-951          1
# 8           Mumbai   5954  economy   G8-334          1
# 9           Mumbai   5954  economy   G8-336          1

# %%
df.stops.unique()
# Out:
# array(['0', '1', '2'], dtype=object)

# %%
df
# Out:
#          airline departure_time source_city  duration stops   arrival_time  \
# 0       SpiceJet        Evening       Delhi      2.17     0          Night
# 1       SpiceJet  Early Morning       Delhi      2.33     0        Morning
# 2        AirAsia  Early Morning       Delhi      2.17     0  Early Morning
# 3        Vistara        Morning       Delhi      2.25     0      Afternoon
# 4        Vistara        Morning       Delhi      2.33     0        Morning
# ...          ...            ...         ...       ...   ...            ...
# 300256   Vistara        Morning     Chennai     10.08     1        Evening
# 300257   Vistara      Afternoon     Chennai     10.42     1          Night
# 300258   Vistara  Early Morning     Chennai     13.83     1          Night
# 300259   Vistara  Early Morning     Chennai     10.00     1        Evening
# 300260   Vistara        Morning     Chennai     10.08     1        Evening
#
#        destination_city  price     class   flight  days_left
# 0                Mumbai   5953   economy  SG-8709          1
# 1                Mumbai   5953   economy  SG-8157          1
# 2                Mumbai   5956   economy   I5-764          1
# 3                Mumbai   5955   economy   UK-995          1
# 4                Mumbai   5955   economy   UK-963          1
# ...                 ...    ...       ...      ...        ...
# 300256        Hyderabad  69265  business   UK-822         49
# 300257        Hyderabad  77105  business   UK-826         49
# 300258        Hyderabad  79099  business   UK-832         49
# 300259        Hyderabad  81585  business   UK-828         49
# 300260        Hyderabad  81585  business   UK-822         49
#
# [300261 rows x 11 columns]

# %%
# arranging the features
df= df[["airline","flight","source_city","departure_time","stops",
     "arrival_time","destination_city","class","duration","days_left","price"]]

# %%
df.head(50)
# Out:
#       airline   flight source_city departure_time stops   arrival_time  \
# 0    SpiceJet  SG-8709       Delhi        Evening     0          Night
# 1    SpiceJet  SG-8157       Delhi  Early Morning     0        Morning
# 2     AirAsia   I5-764       Delhi  Early Morning     0  Early Morning
# 3     Vistara   UK-995       Delhi        Morning     0      Afternoon
# 4     Vistara   UK-963       Delhi        Morning     0        Morning
# 5     Vistara   UK-945       Delhi        Morning     0      Afternoon
# 6     Vistara   UK-927       Delhi        Morning     0        Morning
# 7     Vistara   UK-951       Delhi      Afternoon     0        Evening
# 8    GO FIRST   G8-334       Delhi        Morning     0        Morning
# 9    GO FIRST   G8-336       Delhi      Afternoon     0        Evening
# 10   GO FIRST   G8-392       Delhi      Afternoon     0        Evening
# 11   GO FIRST   G8-338       Delhi        Morning     0      Afternoon
# 12     Indigo  6E-5001       Delhi  Early Morning     0        Morning
# 13     Indigo  6E-6202       Delhi      Afternoon     0      Afternoon
# 14     Indigo   6E-549       Delhi      Afternoon     0        Evening
# 15     Indigo  6E-6278       Delhi        Morning     0        Morning
# 16  Air India   AI-887       Delhi  Early Morning     0        Morning
# 17  Air India   AI-665       Delhi        Morning     0        Morning
# 18    AirAsia   I5-747       Delhi        Evening     1  Early Morning
# 19    AirAsia   I5-747       Delhi        Evening     1        Morning
# 20   GO FIRST   G8-266       Delhi  Early Morning     1        Evening
# 21   GO FIRST   G8-101       Delhi  Early Morning     1          Night
# 22   GO FIRST   G8-103       Delhi        Evening     1        Morning
# 23  Air India   AI-441       Delhi        Evening     1          Night
# 24     Indigo  6E-5328       Delhi        Morning     0      Afternoon
# 25    Vistara   UK-933       Delhi      Afternoon     0        Evening
# 26     Indigo  6E-2046       Delhi        Evening     0        Evening
# 27    AirAsia   I5-744       Delhi        Morning     1      Afternoon
# 28   SpiceJet  SG-8169       Delhi        Evening     0          Night
# 29     Indigo  6E-5041       Delhi        Evening     0          Night
# 30   GO FIRST   G8-165       Delhi  Early Morning     1      Afternoon
# 31     Indigo  6E-2373       Delhi      Afternoon     1        Evening
# 32    Vistara   UK-813       Delhi        Evening     1        Morning
# 33    Vistara   UK-817       Delhi        Evening     1        Morning
# 34    Vistara   UK-819       Delhi      Afternoon     1        Morning
# 35    Vistara   UK-801       Delhi        Morning     1        Morning
# 36    Vistara   UK-815       Delhi        Morning     1        Morning
# 37  Air India   AI-453       Delhi  Early Morning     1      Afternoon
# 38   SpiceJet  SG-2976       Delhi        Evening     1          Night
# 39   SpiceJet  SG-2976       Delhi        Evening     1        Morning
# 40  Air India   AI-504       Delhi          Night     1        Morning
# 41  Air India   AI-502       Delhi      Afternoon     1        Morning
# 42  Air India   AI-506       Delhi        Morning     1        Morning
# 43  Air India   AI-803       Delhi  Early Morning     1        Morning
# 44  Air India   AI-479       Delhi          Night     1      Afternoon
# 45   SpiceJet   SG-339       Delhi        Evening     1      Afternoon
# 46    Vistara   UK-955       Delhi        Evening     0          Night
# 47    Vistara   UK-627       Delhi      Afternoon     1        Evening
# 48    AirAsia   I5-784       Delhi        Evening     1  Early Morning
# 49  Air India  AI-9643       Delhi        Evening     1      Afternoon
#
#    destination_city    class  duration  days_left  price
# 0            Mumbai  economy      2.17          1   5953
# 1            Mumbai  economy      2.33          1   5953
# 2            Mumbai  economy      2.17          1   5956
# 3            Mumbai  economy      2.25          1   5955
# 4            Mumbai  economy      2.33          1   5955
# 5            Mumbai  economy      2.33          1   5955
# 6            Mumbai  economy      2.08          1   6060
# 7            Mumbai  economy      2.17          1   6060
# 8            Mumbai  economy      2.17          1   5954
# 9            Mumbai  economy      2.25          1   5954
# 10           Mumbai  economy      2.25          1   5954
# 11           Mumbai  economy      2.33          1   5954
# 12           Mumbai  economy      2.17          1   5955
# 13           Mumbai  economy      2.17          1   5955
# 14           Mumbai  economy      2.25          1   5955
# 15           Mumbai  economy      2.33          1   5955
# 16           Mumbai  economy      2.08          1   5955
# 17           Mumbai  economy      2.17          1   5955
# 18           Mumbai  economy     12.25          1   5949
# 19           Mumbai  economy     16.33          1   5949
# 20           Mumbai  economy     11.75          1   5954
# 21           Mumbai  economy     14.50          1   5954
# 22           Mumbai  economy     15.67          1   5954
# 23           Mumbai  economy      3.75          1   5955
# 24           Mumbai  economy      2.50          1   6165
# 25           Mumbai  economy      2.17          1   6690
# 26           Mumbai  economy      2.17          1   6585
# 27           Mumbai  economy      5.83          1   8869
# 28           Mumbai  economy      2.33          1  10260
# 29           Mumbai  economy      2.17          1  10470
# 30           Mumbai  economy      8.00          1  10575
# 31           Mumbai  economy      6.00          1  10838
# 32           Mumbai  economy     14.67          1  12150
# 33           Mumbai  economy     16.17          1  12150
# 34           Mumbai  economy     18.00          1  12150
# 35           Mumbai  economy     23.17          1  12150
# 36           Mumbai  economy     24.17          1  12150
# 37           Mumbai  economy      8.83          1  11900
# 38           Mumbai  economy      4.50          1  12123
# 39           Mumbai  economy     15.25          1  12123
# 40           Mumbai  economy     11.00          1  12150
# 41           Mumbai  economy     19.08          1  12150
# 42           Mumbai  economy     22.83          1  12150
# 43           Mumbai  economy     26.42          1  12150
# 44           Mumbai  economy     17.75          1  12215
# 45           Mumbai  economy     19.58          1  12230
# 46           Mumbai  economy      2.33          1  12780
# 47           Mumbai  economy     26.67          1  12885
# 48           Mumbai  economy     15.17          1  12539
# 49           Mumbai  economy     20.83          1  12938

# %% [markdown]
# #### now we have clean data for our model
#
# #### The various features of the cleaned dataset are explained below:
#
# ##### 1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
#
# ##### 2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
#
# ##### 3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
#
# ##### 4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure time and have 6 unique time labels.
#
# ##### 5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
#
# ##### 6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps information about the arrival time.
#
# ##### 7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
#
# ##### 8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
#
# ##### 9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.
#
# ##### 10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
#
# ##### 11) Price: Target variable stores information of the ticket price.

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">EDA</h1>
#
# </div>

# %%
# getting no null values in the data frame
df.isna().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
# getting all the details of the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300261 non-null  object
#  1   flight            300261 non-null  object
#  2   source_city       300261 non-null  object
#  3   departure_time    300261 non-null  object
#  4   stops             300261 non-null  object
#  5   arrival_time      300261 non-null  category
#  6   destination_city  300261 non-null  object
#  7   class             300261 non-null  object
#  8   duration          300261 non-null  float64
#  9   days_left         300261 non-null  int32
#  10  price             300261 non-null  int32
# dtypes: category(1), float64(1), int32(2), object(7)
# memory usage: 20.9+ MB

# %%
# getting all statical insights of the numarical features 
df.describe()
# Out:
#             duration      days_left          price
# count  300261.000000  300261.000000  300261.000000
# mean       12.219142      26.004473   20883.717666
# std         7.200348      13.560985   22695.911266
# min         0.830000       1.000000    1105.000000
# 25%         6.750000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max       103.000000      49.000000  123071.000000

# %%
# we has two duplicte rows
df.duplicated().sum()
# Out:
# 2

# %%
# checking what are the values for each category in airline feature
df["airline"].value_counts().plot(kind = "bar",cmap='flag')
plt.title('Airlines',fontsize=15)
plt.xlabel('Airlines')
plt.show()

# %%
# # checking what are the percentage values for each category in source_city
plt.figure(figsize = (5,5))
df['source_city'].value_counts().plot(kind = "pie", textprops={'color':'black'}, autopct = "%.2f",cmap = "summer" )
plt.title('Source City',fontsize=15)
plt.show()

# %%
# checking what are the percentage values for each category in departure time
plt.figure(figsize = (5,5))
df['departure_time'].value_counts().plot(kind = "pie",autopct = "%.2f",cmap = "winter_r" )
plt.title('departure time',fontsize=15)
plt.show()

# %%
# checking what are the percentage values for each category in stops feature
plt.figure(figsize = (5,5))
df['stops'].value_counts().plot(kind = "pie", textprops={'color':'black'}, autopct = "%.2f",cmap = "spring" )
plt.title('stops',fontsize=15)
plt.legend([1,0,2])
plt.show()

# %%
# checking what are the percentage values for each category in arrival time feature
plt.figure(figsize = (5,5))
df['arrival_time'].value_counts().plot(kind = "pie",autopct = "%.2f",cmap = "rainbow" )
plt.title('arrival time',fontsize=15)
plt.show()

# %%
# checking what are the percentage values for each category in destination city feature
plt.figure(figsize = (5,5))
df['destination_city'].value_counts().plot(kind = "pie",autopct = "%.2f",cmap = "cool" )
plt.title('destination city',fontsize=15)
plt.show()

# %%
# checking what are the percentage values for each category in ticket class feature
plt.figure(figsize = (5,5))
df['class'].value_counts().plot(kind = "pie",autopct = "%.2f",cmap = "summer" )
plt.title('Ticket Class',fontsize=15)
plt.show()

# %%
# checking distribution of the duration 
sns.distplot(df["duration"],hist = False,color = "green")
plt.show()

# %%
# checking distribution of the days
df["days_left"].plot(kind = "kde", cmap = "summer")
plt.show()

# %% [markdown]
# ##### Q1. Does price vary with Airlines?
# ###### Ans: The answer is yes Trujet is the cheapest airline and Vistara is the most expansive one.

# %%
#s = df.groupby("airline")["price"].mean().sort_values()
s.plot(kind = "barh",cmap = "winter_r")
plt.ylabel("AIRLINE")
plt.xlabel("AVG PRICE")
plt.title("AVERAGE PRICE OF EACH AIRLINE")
plt.show()

# %% [markdown]
# ##### Q2. How is the price affected when tickets are bought in just 1 or 2 days before departure?¶
# ##### Ans: Yes price is affected when tickets are bought in just 1 or 2 days before#####

# %%
#plt.figure(figsize = (15,5))
s = df.groupby(["days_left"])["price"].max().sort_values()
s.plot(kind = "bar",cmap = "winter_r")
plt.ylabel("AVG PRICE")
plt.xlabel("DAYS BEFORE DEPARTURE")
plt.title("AVERAGE PRICE ON THE BASIS OF DAYS BEFORE DEPARTURE ")
plt.show()

# %% [markdown]
# ##### Q3. Does ticket price change based on the departure time and arrival time?
# ##### Ans: 1. departure vs ticket price
#
# ##### Ticket Price is More for the Flights when the Departure Time is at Night
#
# ##### Ticket Price is almost equal for flights Having Departure time at Early_morning , Morning and Evening
#
# ##### Ticket Price is Low for the Flights Having Departure Time at Late_night

# %% [markdown]
# ##### 2. Arrival Time Vs Ticket Price
#
# ##### Ticket Price is More for the Flights when the Arrival Time is at Evening
#
# ##### Ticket Price is almost equal for flights Having Arrival time is at Morning and Night
#
# ###### Ticket Price is Low for the Flights Having Arrival Time at Late_night as same as Departure Time

# %%
sns.catplot(x='arrival_time',y='price',kind='strip',data=df,color = "c",aspect = 2)

# %%
sns.catplot(x='departure_time',y='price',kind='strip',data=df,color = "c",aspect = 2)

# %% [markdown]
# #### Q4. How the price changes with change in Source and Destination?
# #### Ans: 1. Source City Vs Ticket Price
#
# #### Ticket Price is More for the Flights whose Source City is Kolkata
#
# #### Ticket Price is almost equal for flights Having Source Cities as Mumbai and chennai , delhi and Bangalore
#
# #### Ticket Price is Low for the Flights Having Source City as Hydrabad
#
# #### 2. Destination City Vs Ticket Price
#
# #### Ticket Price is More for the Flights whose Destination City is kolkata and Delhi
#
# #### Ticket Price is almost equal for flights Having Destination Cities as Mumbai and Bangalore
#
# #### Ticket Price is Low for the Flights Having Destination City as Chennai

# %%
sns.catplot(x='source_city',y='price',kind='strip',data=df,color = "y",aspect = 2)

# %%
sns.catplot(x='destination_city',y='price',kind='strip',data=df,color = "g",aspect = 2)

# %%
# The price variation between source and destination in each airline
df.groupby(['airline','source_city','destination_city'],as_index=False)['price'].mean()
# Out:
#        airline source_city destination_city         price
# 0    Air India   Bangalore          Chennai  26765.567702
# 1    Air India   Bangalore            Delhi  20699.099886
# 2    Air India   Bangalore        Hyderabad  23395.956912
# 3    Air India   Bangalore          Kolkata  29105.826259
# 4    Air India   Bangalore           Mumbai  25625.530802
# ..         ...         ...              ...           ...
# 178    Vistara      Mumbai        Bangalore  35029.880315
# 179    Vistara      Mumbai          Chennai  32181.946251
# 180    Vistara      Mumbai            Delhi  26402.695114
# 181    Vistara      Mumbai        Hyderabad  29497.578017
# 182    Vistara      Mumbai          Kolkata  35223.862417
#
# [183 rows x 4 columns]

# %%
# here is the average price between city 
pd.pivot_table(data = df,columns = "source_city",index = "destination_city", values = "price")
# Out:
# source_city          Bangalore       Chennai         Delhi     Hyderabad  \
# destination_city
# Bangalore                  NaN  25081.850454  17880.216315  21245.945429
# Chennai           23321.850078           NaN  19369.881354  21848.065989
# Delhi             17723.313972  18981.863948           NaN  17242.639473
# Hyderabad         21152.051053  21591.345404  17347.288379           NaN
# Kolkata           23498.234221  22669.932407  20566.409418  20823.893201
# Mumbai            23127.231376  22765.849647  19354.405336  20065.715179
#
# source_city            Kolkata        Mumbai
# destination_city
# Bangalore         22744.808428  23147.873807
# Chennai           23660.361040  22781.899112
# Delhi             19422.354559  18725.320008
# Hyderabad         21500.011397  20992.128567
# Kolkata                    NaN  22379.146723
# Mumbai            22078.883579           NaN

# %%
# Plotting the information regarding price variance between cities
_ = pd.crosstab(columns = df["source_city"],index = df["destination_city"], values = df["price"], aggfunc="mean")
_.plot(kind = "bar",figsize = (15,5))
# Out:
# <AxesSubplot: xlabel='destination_city'>

# %%
# we can plot strip plot to look at the price variation in between cities
sns.catplot(data = df, x = "source_city", y = "price", 
            hue = "destination_city", jitter = 0.3, aspect = 2,height = 7)

# %% [markdown]
# #### Q5. How does the ticket price vary between Economy and Business class?¶
# #### Ans: The business class price is higher than economy class

# %%
sns.catplot(data = df, x = "class", y = "price", aspect = 1,height = 5)

# %%
sns.catplot(data = df, x = "airline", y = "price", 
            hue = "class", jitter = 0.2, aspect = 2,height = 5)

# %%
#  We can see that we have outliers in duration feature but we will not replace them
#  in place of replacing them we will reduce their effect as it is 
#  the real time, which is taken by flight from source and destination
df.boxplot(column ="duration")
# Out:
# <AxesSubplot: >

# %%
df.boxplot(column ="days_left") # no outliers are found
# Out:
# <AxesSubplot: >

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">FEATURE ENGINEERING</h1>
#
# </div>

# %%
# dropping the duplicate rows
df.drop_duplicates(inplace = True)

# %%
#as we have seen that we are getting information from airline so we have no need for flight feature
df1 = df.drop("flight", axis = 1)
df1.head(1)
# Out:
#     airline source_city departure_time stops arrival_time destination_city  \
# 0  SpiceJet       Delhi        Evening     0        Night           Mumbai
#
#      class  duration  days_left  price
# 0  economy      2.17          1   5953

# %%
df1["departure_time"].replace({'Late Night':0,'Early Morning':1,'Morning':2,
                               'Afternoon':3,'Evening':4,'Night':5},inplace=True)
df1["arrival_time"].replace({'Late Night':0,'Early Morning':1,'Morning':2,
                             'Afternoon':3,'Evening':4,'Night':5},inplace=True)
df1["class"].replace({"economy":0,"business":1},inplace=True)
df1.head(3)
# Out:
#     airline source_city  departure_time stops arrival_time destination_city  \
# 0  SpiceJet       Delhi               4     0            5           Mumbai
# 1  SpiceJet       Delhi               1     0            2           Mumbai
# 2   AirAsia       Delhi               1     0            1           Mumbai
#
#    class  duration  days_left  price
# 0      0      2.17          1   5953
# 1      0      2.33          1   5953
# 2      0      2.17          1   5956

# %%
# encoding for nominal data (we will use onehot encoder)

ohe = OneHotEncoder()
df1[list(df1["airline"].unique())] = ohe.fit_transform(df1[["airline"]]).A 
# making sparse metrics to metrics
df1 = pd.concat([df1,pd.get_dummies(df1["destination_city"],prefix = "destination_city")], axis = 1)
df1 = pd.concat([df1,pd.get_dummies(df1["source_city"],prefix = "source_city")], axis = 1)
df1.drop(["airline","source_city","destination_city"],axis = 1,inplace=True)
df1.head(1)
# Out:
#    departure_time stops arrival_time  class  duration  days_left  price  \
# 0               4     0            5      0      2.17          1   5953
#
#    SpiceJet  AirAsia  Vistara  ...  destination_city_Delhi  \
# 0       0.0      0.0      0.0  ...                       0
#
#    destination_city_Hyderabad  destination_city_Kolkata  \
# 0                           0                         0
#
#    destination_city_Mumbai  source_city_Bangalore  source_city_Chennai  \
# 0                        1                      0                    0
#
#    source_city_Delhi  source_city_Hyderabad  source_city_Kolkata  \
# 0                  1                      0                    0
#
#    source_city_Mumbai
# 0                   0
#
# [1 rows x 27 columns]

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">FEATURE SELECTION</h1>
#
# </div>

# %%
# As we can see there is low dimentionality of the data no need for high feature selections
# if we will drop some featuers so there is high chances that our model will be undercutted. 
# That's why we will see the model perfomance without feature selection first.

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">MODEL SELECTION AND TRAINING</h1>
#
# </div>

# %%
# seperating the dependent and independent variables
x = df1.drop("price", axis = 1)
y = df1["price"]

# %%
# splitting the data for training as well as testing purpose
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">MODEL BUILDING</h1>
#
# </div>

# %%
models={
    'LinearRegression':LinearRegression(),
    'Decision Tree':DecisionTreeRegressor(),
    'AdaBoostRegressor':AdaBoostRegressor(),
    'RandomForestRegressor':RandomForestRegressor(random_state=0)
    
}

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">WITHOUT SCALING MODEL PERFORMANCES</h1>
#
# </div>

# %%
for name, model in models.items():
    model.fit(x_train, y_train)
    print('Performance of model trained without scaling using {}'.format(name))
    training_score = model.score(x_train, y_train)*100
    testing_score= model.score(x_test,y_test)*100
    score =r2_score(y_test,model.predict(x_test))*100
    mae = mean_absolute_error(y_test,model.predict(x_test))
    mse=mean_squared_error(y_test,model.predict(x_test))
    rmse=np.sqrt(mse)
    print("r2score",score)
    print("training_score:",training_score)
    print("testing_score:",testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test",rmse)
    print("*"*100)
# Out:
# Performance of model trained without scaling using LinearRegression
# r2score 91.01065276667426
# training_score: 90.93493429288637
# testing_score: 91.01065276667426
# mae: 4516.325269717395
# mse: 46308872.30654299
# rmse_test 6805.062255890316
# ****************************************************************************************************
# Performance of model trained without scaling using Decision Tree
# r2score 97.64627229325521
# training_score: 99.9382532773985
# testing_score: 97.64627229325521
# mae: 1180.4875478540525
# mse: 12125293.74902021
# rmse_test 3482.1392489416917
# ****************************************************************************************************
# Performance of model trained without scaling using AdaBoostRegressor
# r2score 93.65829027641959
# training_score: 93.68859430142953
# testing_score: 93.65829027641959
# mae: 3581.198693749551
# mse: 32669494.03241558
# rmse_test 5715.723404120915
# ****************************************************************************************************
# Performance of model trained without scaling using RandomForestRegressor
# r2score 98.52096393872048
# training_score: 99.74917035981835
# testing_score: 98.52096393872048
# mae: 1098.5491253594762
# mse: 7619295.408308038
# rmse_test 2760.3071220985607
# ****************************************************************************************************

# %%
# scalling the data 
# to skip data leackage we will fit only on training data 
std = StandardScaler()
x_train = pd.DataFrame(std.fit_transform(x_train), columns = x_train.columns)
x_test = pd.DataFrame(std.transform(x_test),columns = x_test.columns)

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">WITH SCALING MODEL PERFORMANCES</h1>
#
# </div>

# %%
for name, model in models.items():
    model.fit(x_train, y_train)
    print('Performance of model trained with scaling using {}'.format(name))
    training_score = model.score(x_train, y_train)*100
    testing_score= model.score(x_test,y_test)*100
    score =r2_score(y_test,model.predict(x_test))*100
    mae = mean_absolute_error(y_test,model.predict(x_test))
    mse=mean_squared_error(y_test,model.predict(x_test))
    rmse=np.sqrt(mse)
    print("r2score",score)
    print("training_score:",training_score)
    print("testing_score:",testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test",rmse)
    print("*"*100)
# Out:
# Performance of model trained with scaling using LinearRegression
# r2score 91.01075868800908
# training_score: 90.93483879831061
# testing_score: 91.01075868800908
# mae: 4516.336970616512
# mse: 46308326.6498405
# rmse_test 6805.022163802297
# ****************************************************************************************************
# Performance of model trained with scaling using Decision Tree
# r2score 97.66569075415588
# training_score: 99.9382532773985
# testing_score: 97.66569075415588
# mae: 1173.0434942036882
# mse: 12025259.007575909
# rmse_test 3467.745522320793
# ****************************************************************************************************
# Performance of model trained with scaling using AdaBoostRegressor
# r2score 93.21732881773245
# training_score: 93.2416107564419
# testing_score: 93.21732881773245
# mae: 3779.7942861205793
# mse: 34941119.25195837
# rmse_test 5911.101356934963
# ****************************************************************************************************
# Performance of model trained with scaling using RandomForestRegressor
# r2score 98.52670630437784
# training_score: 99.74936765514326
# testing_score: 98.52670630437784
# mae: 1095.1599429386977
# mse: 7589713.451903231
# rmse_test 2754.9434571154507
# ****************************************************************************************************

# %% [markdown]
# ##### as we can see the random forest has good r2 values at the time of training as well as testing also has lowest %mae. so we will go with the random forest model. NO need to optimise model

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Model Training</h1>
#
# </div>

# %%
# Training the model
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# <div style="background-color: orange; padding: 10px; text-align: center;">
#
# <h1 style="font-weight: bold; font-style: italic;">Evaluation</h1>
#
# </div>

# %%
# predicting the values
y_pred = rf.predict(x_test)
y_pred
# Out:
# array([35573.28, 38099.  , 10825.89, ...,  1604.  , 11031.97, 64688.2 ])

# %%
PREDICTRION= pd.DataFrame(zip(y,y_pred),columns=('ACTUAL','PREDICTED'),dtype=float)

# %%
PREDICTRION
# Out:
#        ACTUAL  PREDICTED
# 0      5953.0   35573.28
# 1      5953.0   38099.00
# 2      5956.0   10825.89
# 3      5955.0    3869.74
# 4      5955.0    7525.34
# ...       ...        ...
# 99081  7212.0   53164.00
# 99082  7212.0   52287.00
# 99083  7212.0    1604.00
# 99084  7228.0   11031.97
# 99085  7317.0   64688.20
#
# [99086 rows x 2 columns]

# %%
sns.scatterplot(data=PREDICTRION,x='ACTUAL',y='PREDICTED')
plt.show()

# %%
sns.lineplot(data=PREDICTRION,x='ACTUAL',y='PREDICTED')
plt.show()
